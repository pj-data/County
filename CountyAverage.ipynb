# %%
# https://www.census.gov/data/datasets/2019/econ/cbp
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup
import re
import sys

# %%
# create dataframe for 2018 & 2021
df_cbp18 = pd.read_csv('cbp18cd.csv')
df_cbp21 = pd.read_csv('cbp21cd.csv', thousands = ',')
df_cbp18.head(5)
# Out:
#   State FIPS    State  116th Congressional District 2017 NAICS Code  \
# 0         01  Alabama                           1.0          ------
# 1         01  Alabama                           1.0          11----
# 2         01  Alabama                           1.0          21----
# 3         01  Alabama                           1.0          22----
# 4         01  Alabama                           1.0          23----
#
#                                NAICS Description   Number of Establishments   \
# 0                          Total for all sectors                     15921.0
# 1     Agriculture, forestry, fishing and hunting                       142.0
# 2  Mining, quarrying, and oil and gas extraction                        34.0
# 3                                      Utilities                        56.0
# 4                                   Construction                      1367.0
#
#     Employment  Employment Noise Flag   1st Quarter Payroll ($1,000)   \
# 0      244615.0                     G                       2492282.0
# 1        1127.0                     G                         10591.0
# 2         500.0                     G                         10491.0
# 3        1618.0                     G                         46260.0
# 4       16277.0                     G                        194035.0
#
#   1st Quarter Payroll Noise Flag   Annual Payroll ($1,000)   \
# 0                              G                 10417508.0
# 1                              G                    44855.0
# 2                              H                    41785.0
# 3                              H                   151722.0
# 4                              G                   855500.0
#
#   Annual Payroll Noise Flag
# 0                         G
# 1                         G
# 2                         H
# 3                         H
# 4                         G

# %%
df_cbp21.columns
# Out:
# Index(['State FIPS', 'State', '118th Congressional District',
#        '2017 NAICS Code', 'NAICS Description', ' Number of Establishments ',
#        ' Employment ', 'Employment Noise Flag',
#        ' 1st Quarter Payroll ($1,000) ', '1st Quarter Payroll Noise Flag',
#        ' Annual Payroll ($1,000) ', 'Annual Payroll Noise Flag'],
#       dtype='object')

# %%
# Finding un-necessary rows which are not useful for data analytics
df_cbp18.loc[df_cbp18['NAICS Description'] == 'Total for all sectors'].head()
# Out:
#    State FIPS    State  116th Congressional District 2017 NAICS Code  \
# 0          01  Alabama                           1.0          ------
# 21         01  Alabama                           2.0          ------
# 42         01  Alabama                           3.0          ------
# 63         01  Alabama                           4.0          ------
# 84         01  Alabama                           5.0          ------
#
#         NAICS Description   Number of Establishments    Employment   \
# 0   Total for all sectors                     15921.0      244615.0
# 21  Total for all sectors                     14184.0      216247.0
# 42  Total for all sectors                     11746.0      187543.0
# 63  Total for all sectors                     12581.0      191868.0
# 84  Total for all sectors                     15250.0      270428.0
#
#    Employment Noise Flag   1st Quarter Payroll ($1,000)   \
# 0                      G                       2492282.0
# 21                     G                       2089913.0
# 42                     G                       1640393.0
# 63                     G                       1720901.0
# 84                     G                       3235343.0
#
#    1st Quarter Payroll Noise Flag   Annual Payroll ($1,000)   \
# 0                               G                 10417508.0
# 21                              G                  8582686.0
# 42                              G                  6740794.0
# 63                              G                  7021599.0
# 84                              G                 13159970.0
#
#    Annual Payroll Noise Flag
# 0                          G
# 21                         G
# 42                         G
# 63                         G
# 84                         G

# %%
df_cbp18.columns
# Out:
# Index(['State FIPS', 'State', '116th Congressional District',
#        '2017 NAICS Code', 'NAICS Description', ' Number of Establishments ',
#        ' Employment ', 'Employment Noise Flag',
#        ' 1st Quarter Payroll ($1,000) ', '1st Quarter Payroll Noise Flag',
#        ' Annual Payroll ($1,000) ', 'Annual Payroll Noise Flag'],
#       dtype='object')

# %%
# dropping columns & rows. data cleaning
df_cbp18 = ((df_cbp18.drop(['State FIPS', '2017 NAICS Code', 'Employment Noise Flag',' 1st Quarter Payroll ($1,000) ', 
                          '1st Quarter Payroll Noise Flag','Annual Payroll Noise Flag'], axis = 1)
                          .drop(df_cbp18.loc[df_cbp18['NAICS Description'] == 'Total for all sectors'].index, axis=0)
                          .dropna(axis=0)))
df_cbp21 = ((df_cbp21.drop(['State FIPS', '2017 NAICS Code', 'Employment Noise Flag',' 1st Quarter Payroll ($1,000) ', 
                          '1st Quarter Payroll Noise Flag','Annual Payroll Noise Flag'], axis = 1)
                          .drop(df_cbp21.loc[df_cbp21['NAICS Description'] == 'Total for all sectors'].index, axis=0)
                          .dropna(axis=0)))

# %%
# add one column of AverageSalary by multiplying Annual Payroll($1000) with 1000 & dividing it to Employment. For 2018 
df_cbp18['AverageSalary_18'] = ((df_cbp18[' Annual Payroll ($1,000) ']*1000) / (df_cbp18[' Employment '])).round()
#df_cbp18

# %%
# add one column of AverageSalary by multiplying Annual Payroll($1000) with 1000 & dividing it to Employment. For 2021
df_cbp21['AverageSalary_21'] = ((df_cbp21[' Annual Payroll ($1,000) '] * 1000) / df_cbp21[' Employment ']).round()

# %%
#calculate max average salary per state & 116th congressional district for 2018
CountyMax_18 = df_cbp18.groupby(['State','116th Congressional District']).agg({'AverageSalary_18':np.max}).reset_index()   
CountyMax_18
# Out:
#          State  116th Congressional District  AverageSalary_18
# 0      Alabama                           1.0          101567.0
# 1      Alabama                           2.0          101712.0
# 2      Alabama                           3.0           78545.0
# 3      Alabama                           4.0           89785.0
# 4      Alabama                           5.0           93189.0
# ..         ...                           ...               ...
# 432  Wisconsin                           5.0          104394.0
# 433  Wisconsin                           6.0          153960.0
# 434  Wisconsin                           7.0           90396.0
# 435  Wisconsin                           8.0           98622.0
# 436    Wyoming                           0.0           94753.0
#
# [437 rows x 3 columns]

# %%
#calculate max average salary per state & 116th congressional district for 2021
CountyMax_21 = df_cbp21.groupby(['State','118th Congressional District']).agg({'AverageSalary_21':np.max}).reset_index()

# %%
# create a subset of max average salary per state & 116th congressional district from dataframe of 2018.
df18_merge = CountyMax_18.merge(df_cbp18, on = ['State', '116th Congressional District', 'AverageSalary_18'], how = 'inner')

# %%
# create a subset of max average salary per state & 118th congressional district from dataframe of 2021.
df21_merge = CountyMax_21.merge(df_cbp21, on = ['State', '118th Congressional District', 'AverageSalary_21'], how = 'inner')

# %%
df18_merge
# Out:
#          State  116th Congressional District  AverageSalary_18  \
# 0      Alabama                           1.0          101567.0
# 1      Alabama                           2.0          101712.0
# 2      Alabama                           3.0           78545.0
# 3      Alabama                           4.0           89785.0
# 4      Alabama                           5.0           93189.0
# ..         ...                           ...               ...
# 432  Wisconsin                           5.0          104394.0
# 433  Wisconsin                           6.0          153960.0
# 434  Wisconsin                           7.0           90396.0
# 435  Wisconsin                           8.0           98622.0
# 436    Wyoming                           0.0           94753.0
#
#                                  NAICS Description  \
# 0          Management of companies and enterprises
# 1                                        Utilities
# 2    Mining, quarrying, and oil and gas extraction
# 3          Management of companies and enterprises
# 4                                        Utilities
# ..                                             ...
# 432  Mining, quarrying, and oil and gas extraction
# 433  Mining, quarrying, and oil and gas extraction
# 434                                      Utilities
# 435                                      Utilities
# 436                                      Utilities
#
#       Number of Establishments    Employment    Annual Payroll ($1,000)
# 0                         105.0        3216.0                   326639.0
# 1                          67.0        2860.0                   290897.0
# 2                          18.0         512.0                    40215.0
# 3                          71.0        1500.0                   134677.0
# 4                           8.0         111.0                    10344.0
# ..                          ...           ...                        ...
# 432                        18.0         963.0                   100531.0
# 433                        26.0        3999.0                   615688.0
# 434                        96.0        1296.0                   117153.0
# 435                        56.0        1851.0                   182550.0
# 436                       141.0        2600.0                   246357.0
#
# [437 rows x 7 columns]

# %%
#create subset for california from subset of 2018
california18 = df18_merge.loc[df18_merge.State == 'California'].drop('116th Congressional District', axis = 1)
california18.head(3)
# Out:
#          State  AverageSalary_18 NAICS Description  \
# 21  California          144577.0         Utilities
# 22  California          152064.0       Information
# 23  California          124904.0         Utilities
#
#      Number of Establishments    Employment    Annual Payroll ($1,000)
# 21                        55.0        1175.0                   169878.0
# 22                       499.0        7084.0                  1077224.0
# 23                        43.0        1066.0                   133148.0

# %%
california21 = df21_merge.loc[df21_merge.State == 'California'].drop(' Annual Payroll ($1,000) ', axis = 1)
california21.loc[california21['NAICS Description'] == 'Information']
# Out:
#          State  118th Congressional District  AverageSalary_21  \
# 22  California                           2.0          197057.0
# 30  California                          10.0          193516.0
# 31  California                          11.0          327267.0
# 34  California                          14.0          248708.0
# 35  California                          15.0          440450.0
# 36  California                          16.0          422364.0
# 38  California                          18.0          267823.0
# 67  California                          47.0          166059.0
#
#    NAICS Description   Number of Establishments    Employment
# 22       Information                       499.0        6460.0
# 30       Information                       418.0        8258.0
# 31       Information                      1865.0       91735.0
# 34       Information                       351.0       18622.0
# 35       Information                       592.0       87171.0
# 36       Information                       978.0       74674.0
# 38       Information                       269.0        9135.0
# 67       Information                       807.0       20228.0

# %%
# concat two subset of california for 2018 & 2021
result = (pd.concat([california18, california21], axis = 1, join = 'inner')
          .drop(['State','State','118th Congressional District'], axis=1)
          .reset_index())

# %%
# drop unnecessary columns
result = result.drop(['index',' Annual Payroll ($1,000) '], axis = 1)

# %%
col_lis = list(result.columns)
col_lis
# Out:
# ['AverageSalary_18',
#  'NAICS Description',
#  ' Number of Establishments ',
#  ' Employment ',
#  'AverageSalary_21',
#  'NAICS Description',
#  ' Number of Establishments ',
#  ' Employment ']

# %%
# cleaning of columns names & creating more easy to understand names.
for i in range(8):
    if i == 0:
        col_lis[i] = col_lis[i].strip()
        print(col_lis[i])
        pass
    elif 1 <= i < 4:
        col_lis[i] = col_lis[i].strip() + '_18'
        print(col_lis[i])
    elif i == 4:
         print(col_lis[i])
         pass
    else:
        col_lis[i] = col_lis[i].strip() + '_21'
        print(col_lis[i])
# Out:
# AverageSalary_18
# NAICS Description_18
# Number of Establishments_18
# Employment_18
# AverageSalary_21
# NAICS Description_21
# Number of Establishments_21
# Employment_21

# %%
col_lis = col_lis
result.columns = col_lis

# %%
# shows information industry's data in california for 2021
result.loc[result['NAICS Description_21'] == 'Information']
# Out:
#     AverageSalary_18                     NAICS Description_18  \
# 1           152064.0                              Information
# 9           124485.0                                Utilities
# 10          127277.0                                Utilities
# 13          323630.0                              Information
# 14          203946.0  Management of companies and enterprises
# 15          132767.0                                Utilities
# 17          348970.0                              Information
# 46          126773.0                                Utilities
#
#     Number of Establishments_18  Employment_18  AverageSalary_21  \
# 1                         499.0         7084.0          197057.0
# 9                           8.0          297.0          193516.0
# 10                         18.0          249.0          327267.0
# 13                        612.0        53189.0          248708.0
# 14                        189.0        13823.0          440450.0
# 15                         17.0         2261.0          422364.0
# 17                        984.0        66275.0          267823.0
# 46                         30.0          781.0          166059.0
#
#    NAICS Description_21  Number of Establishments_21  Employment_21
# 1           Information                        499.0         6460.0
# 9           Information                        418.0         8258.0
# 10          Information                       1865.0        91735.0
# 13          Information                        351.0        18622.0
# 14          Information                        592.0        87171.0
# 15          Information                        978.0        74674.0
# 17          Information                        269.0         9135.0
# 46          Information                        807.0        20228.0

# %%
result.loc[result['NAICS Description_21'] == 'Arts, entertainment, and  in recreation']
# Out:
# Empty DataFrame
# Columns: [AverageSalary_18, NAICS Description_18, Number of Establishments_18, Employment_18, AverageSalary_21, NAICS Description_21, Number of Establishments_21, Employment_21]
# Index: []

# %%
result.loc[result['NAICS Description_18'] == 'Arts, entertainment, and recreation']
# Out:
#     AverageSalary_18                 NAICS Description_18  \
# 32          162265.0  Arts, entertainment, and recreation
#
#     Number of Establishments_18  Employment_18  AverageSalary_21  \
# 32                       4530.0        18533.0          120758.0
#
#    NAICS Description_21  Number of Establishments_21  Employment_21
# 32            Utilities                         17.0         1126.0

# %%
# code gives the total number of congessional districts where a particular industry pay max average salary for 2021.
result.groupby('NAICS Description_21')['Number of Establishments_21'].count()
# Out:
# NAICS Description_21
# Agriculture, forestry, fishing and hunting           1
# Arts, entertainment, and recreation                  4
# Finance and insurance                                3
# Industries not classified                            2
# Information                                          8
# Management of companies and enterprises              7
# Mining, quarrying, and oil and gas extraction        3
# Professional, scientific, and technical services     1
# Utilities                                           23
# Name: Number of Establishments_21, dtype: int64

# %%
# code gives the total number of congessional districts where a particular industry pay max average salary for 2018.
result.groupby('NAICS Description_18')['Number of Establishments_18'].count()
# Out:
# NAICS Description_18
# Agriculture, forestry, fishing and hunting        1
# Arts, entertainment, and recreation               1
# Finance and insurance                             4
# Information                                       5
# Management of companies and enterprises           5
# Mining, quarrying, and oil and gas extraction     3
# Professional, scientific, and technical           2
# Utilities                                        31
# Name: Number of Establishments_18, dtype: int64

# %%
def highlight_cols(x):
      
    # copy df to new - original data is not changed
    result = x.copy()
      
    # select all values to green color
    result.loc[:, :] = 'background-color: cyan'
      
    # overwrite values grey color
    result[['AverageSalary_18','NAICS Description_18','Number of Establishments_18','Employment_18']] = 'background-color: yellow'
      
    # return color df
    return result 
  
print("Highlighted DataFrame :")

result.style.apply(highlight_cols, axis = None)
# Out:
# Highlighted DataFrame :
# <style  type="text/css" >
#     #T_98171192_8a60_11ee_b464_0c96e6a148c6row0_col0 {
#             background-color:  yellow;
#         }    #T_98171192_8a60_11ee_b464_0c96e6a148c6row0_col1 {
#             background-color:  yellow;
#         }    #T_98171192_8a60_11ee_b464_0c96e6a148c6row0_col2 {
#             background-color:  yellow;
#         }    #T_98171192_8a60_11ee_b464_0c96e6a148c6row0_col3 {
#             background-color:  yellow;
#         }    #T_98171192_8a60_11ee_b464_0c96e6a148c6row0_col4 {
#             background-color:  cyan;
#         }    #T_98171192_8a60_11ee_b464_0c96e6a148c6row0_col5 {
#             background-color:  cyan;
#         }    #T_98171192_8a60_11ee_b464_0c96e6a148c6row0_col6 {
#             background-color:  cyan;
#         }    #T_98171192_8a60_11ee_b464_0c96e6a148c6row0_col7 {
#             background-color:  cyan;
#         }    #T_98171192_8a60_11ee_b464_0c96e6a148c6row1_col0 {
#             background-color:  yellow;
#         }    #T_98171192_8a60_11ee_b464_0c96e6a148c6row1_col1 {
#             background-color:  yellow;
#         }    #T_98171192_8a60_11ee_b464_0c96e6a148c6row1_col2 {
#             background-color:  yellow;
#         }    #T_98171192_8a60_11ee_b464_0c96e6a148c6row1_col3 {
#             background-color:  yellow;
#         }    #T_98171192_8a60_11ee_b464_0c96e6a148c6row1_col4 {
#             background-color:  cyan;
#         }    #T_98171192_8a60_11ee_b464_0c96e6a148c6row1_col5 {
#             background-color:  cyan;
#         }    #T_98171192_8a60_11ee_b464_0c96e6a148c6row1_col6 {
#             background-color:  cyan;
#         }    #T_98171192_8a60_11ee_b464_0c96e6a148c6row1_col7 {
#             background-color:  cyan;
#         }    #T_98171192_8a60_11ee_b464_0c96e6a148c6row2_col0 {
#             background-color:  yellow;
#         }    #T_98171192_8a60_11ee_b464_0c96e6a148c6row2_col1 {
#             background-color:  yellow;
#         }    #T_98171192_8a60_11ee_b464_0c96e6a148c6row2_col2 {
#             background-color:  yellow;
#         }    #T_98171192_8a60_11ee_b464_0c96e6a148c6row2_col3 {
#             background-color:  yellow;
#         }    #T_98171192_8a60_11ee_b464_0c96e6a148c6row2_col4 {
#             background-color:  cyan;
#         }    #T_98171192_8a60_11ee_b464_0c96e6a148c6row2_col5 {
#             background-color:  cyan;
#         }    #T_98171192_8a60_11ee_b464_0c96e6a148c6row2_col6 {
#             background-color:  cyan;
#         }    #T_98171192_8a60_11ee_b464_0c96e6a148c6row2_col7 {
#             background-color:  cyan;
#         }    #T_98171192_8a60_11ee_b464_0c96e6a148c6row3_col0 {
#             background-color:  yellow;
#         }    #T_98171192_8a60_11ee_b464_0c96e6a148c6row3_col1 {
#             background-color:  yellow;
#         }    #T_98171192_8a60_11ee_b464_0c96e6a148c6row3_col2 {
#             background-color:  yellow;
#         }    #T_98171192_8a60_11ee_b464_0c96e6a148c6row3_col3 {
#             background-color:  yellow;
#         }    #T_98171192_8a60_11ee_b464_0c96e6a148c6row3_col4 {
#             background-color:  cyan;
#         }    #T_98171192_8a60_11ee_b464_0c96e6a148c6row3_col5 {
#             background-color:  cyan;
#         }    #T_98171192_8a60_11ee_b464_0c96e6a148c6row3_col6 {
#             background-color:  cyan;
#         }    #T_98171192_8a60_11ee_b464_0c96e6a148c6row3_col7 {
#             background-color:  cyan;
#         }    #T_98171192_8a60_11ee_b464_0c96e6a148c6row4_col0 {
#             background-color:  yellow;
#         }    #T_98171192_8a60_11ee_b464_0c96e6a148c6row4_col1 {
#             background-color:  yellow;
#         }    #T_98171192_8a60_11ee_b464_0c96e6a148c6row4_col2 {
#             background-color:  yellow;
#         }    #T_98171192_8a60_11ee_b464_0c96e6a148c6row4_col3 {
#             background-color:  yellow;
#         }    #T_98171192_8a60_11ee_b464_0c96e6a148c6row4_col4 {
#             background-color:  cyan;
#         }    #T_98171192_8a60_11ee_b464_0c96e6a148c6row4_col5 {
#             background-color:  cyan;
#         }    #T_98171192_8a60_11ee_b464_0c96e6a148c6row4_col6 {
#             background-color:  cyan;
#         }    #T_98171192_8a60_11ee_b464_0c96e6a148c6row4_col7 {
#             background-color:  cyan;
#         }    #T_98171192_8a60_11ee_b464_0c96e6a148c6row5_col0 {
#             background-color:  yellow;
#         }    #T_98171192_8a60_11ee_b464_0c96e6a148c6row5_col1 {
#             background-color:  yellow;
#         }    #T_98171192_8a60_11ee_b464_0c96e6a148c6row5_col2 {
#             background-color:  yellow;
#         }    #T_98171192_8a60_11ee_b464_0c96e6a148c6row5_col3 {
#             background-color:  yellow;
#         }    #T_98171192_8a60_11ee_b464_0c96e6a148c6row5_col4 {
#             background-color:  cyan;
#         }    #T_98171192_8a60_11ee_b464_0c96e6a148c6row5_col5 {
#             background-color:  cyan;
#         }    #T_98171192_8a60_11ee_b464_0c96e6a148c6row5_col6 {
#             background-color:  cyan;
#         }    #T_98171192_8a60_11ee_b464_0c96e6a148c6row5_col7 {
#             background-color:  cyan;
#         }    #T_98171192_8a60_11ee_b464_0c96e6a148c6row6_col0 {
#             background-color:  yellow;
#         }    #T_98171192_8a60_11ee_b464_0c96e6a148c6row6_col1 {
#             background-color:  yellow;
#         }    #T_98171192_8a60_11ee_b464_0c96e6a148c6row6_col2 {
#             background-color:  yellow;
#         }    #T_98171192_8a60_11ee_b464_0c96e6a148c6row6_col3 {
#             background-color:  yellow;
#         }    #T_98171192_8a60_11ee_b464_0c96e6a148c6row6_col4 {
#             background-color:  cyan;
#         }    #T_98171192_8a60_11ee_b464_0c96e6a148c6row6_col5 {
#             background-color:  cyan;
#         }    #T_98171192_8a60_11ee_b464_0c96e6a148c6row6_col6 {
#             background-color:  cyan;
#         }    #T_98171192_8a60_11ee_b464_0c96e6a148c6row6_col7 {
#             background-color:  cyan;
#         }    #T_98171192_8a60_11ee_b464_0c96e6a148c6row7_col0 {
#             background-color:  yellow;
#         }    #T_98171192_8a60_11ee_b464_0c96e6a148c6row7_col1 {
#             background-color:  yellow;
#         }    #T_98171192_8a60_11ee_b464_0c96e6a148c6row7_col2 {
#             background-color:  yellow;
#         }    #T_98171192_8a60_11ee_b464_0c96e6a148c6row7_col3 {
#             background-color:  yellow;
#         }    #T_98171192_8a60_11ee_b464_0c96e6a148c6row7_col4 {
#             background-color:  cyan;
#         }    #T_98171192_8a60_11ee_b464_0c96e6a148c6row7_col5 {
#             background-color:  cyan;
#         }    #T_98171192_8a60_11ee_b464_0c96e6a148c6row7_col6 {
#             background-color:  cyan;
#         }    #T_98171192_8a60_11ee_b464_0c96e6a148c6row7_col7 {
#             background-color:  cyan;
#         }    #T_98171192_8a60_11ee_b464_0c96e6a148c6row8_col0 {
#             background-color:  yellow;
#         }    #T_98171192_8a60_11ee_b464_0c96e6a148c6row8_col1 {
#             background-color:  yellow;
#         }    #T_98171192_8a60_11ee_b464_0c96e6a148c6row8_col2 {
#             background-color:  yellow;
#         }    #T_98171192_8a60_11ee_b464_0c96e6a148c6row8_col3 {
#             background-color:  yellow;
#         }    #T_98171192_8a60_11ee_b464_0c96e6a148c6row8_col4 {
#             background-color:  cyan;
#         }    #T_98171192_8a60_11ee_b464_0c96e6a148c6row8_col5 {
#             background-color:  cyan;
#         }    #T_98171192_8a60_11ee_b464_0c96e6a148c6row8_col6 {
#             background-color:  cyan;
#         }    #T_98171192_8a60_11ee_b464_0c96e6a148c6row8_col7 {
#             background-color:  cyan;
#         }    #T_98171192_8a60_11ee_b464_0c96e6a148c6row9_col0 {
#             background-color:  yellow;
#         }    #T_98171192_8a60_11ee_b464_0c96e6a148c6row9_col1 {
#             background-color:  yellow;
#         }    #T_98171192_8a60_11ee_b464_0c96e6a148c6row9_col2 {
#             background-color:  yellow;
#         }    #T_98171192_8a60_11ee_b464_0c96e6a148c6row9_col3 {
#             background-color:  yellow;
#         }    #T_98171192_8a60_11ee_b464_0c96e6a148c6row9_col4 {
#             background-color:  cyan;
#         }    #T_98171192_8a60_11ee_b464_0c96e6a148c6row9_col5 {
#             background-color:  cyan;
#         }    #T_98171192_

# %%
# web scrapping to get congessional districts name from web.
url = r'https://en.wikipedia.org/wiki/California%27s_congressional_districts'

page = requests.get(url)

soup = BeautifulSoup(page.text, 'html.parser')

# %%
#create congressional districts name list with beautifulsoup module
cong_dis = []
for i in soup.find_all('span', style = True):
    cong_dis.append(i.text.replace('(','').replace(')',''))
cong_dis = cong_dis[2:54]

# %%
'''result['districts'] = soup.find_all('span', style = True)[2:]
result['districts'].astype(str)[0][-20:-12]
'''
# Out:
# "result['districts'] = soup.find_all('span', style = True)[2:]\nresult['districts'].astype(str)[0][-20:-12]\n"

# %%
# create congressional districts name column & inserting at starting position
result.insert(0, 'Cong_Dis', cong_dis)
result.index = result.index + 1
result.head(3)
# Out:
#      Cong_Dis  AverageSalary_18 NAICS Description_18  \
# 1    Richvale          144577.0            Utilities
# 2  San Rafael          152064.0          Information
# 3     Rocklin          124904.0            Utilities
#
#    Number of Establishments_18  Employment_18  AverageSalary_21  \
# 1                         55.0         1175.0          151783.0
# 2                        499.0         7084.0          197057.0
# 3                         43.0         1066.0          156769.0
#
#   NAICS Description_21  Number of Establishments_21  Employment_21
# 1            Utilities                         72.0         1536.0
# 2          Information                        499.0         6460.0
# 3            Utilities                         47.0         2143.0

# %%
result.loc[result['NAICS Description_18'] != result['NAICS Description_21']]
# Out:
#                Cong_Dis  AverageSalary_18  \
# 6             Elk Grove          112070.0
# 8          Walnut Grove          105096.0
# 10              Concord          124485.0
# 11        San Francisco          127277.0
# 15  South San Francisco          203946.0
# 16           Menlo Park          132767.0
# 19        Carmel Valley          211093.0
# 20          Bakersfield          124774.0
# 22              Hanford          118567.0
# 23        Big Bear Lake          107359.0
# 25          Palm Desert          145948.0
# 26     Westlake Village          128072.0
# 27        Santa Clarita          133839.0
# 28        Monterey Park          127510.0
# 29          Los Angeles           92973.0
# 30              Burbank          180664.0
# 31              Norwalk           87309.0
# 32          Los Angeles           90032.0
# 33             Redlands          162265.0
# 36             Torrance          111000.0
# 39            Riverside          118709.0
# 40             La Habra           93729.0
# 41               Corona           85607.0
# 44          Los Angeles          131750.0
# 45           Seal Beach          157688.0
# 47               Irvine          126773.0
# 48                Vista          156148.0
# 51            San Diego          102891.0
# 52            San Diego          129191.0
#
#                              NAICS Description_18  \
# 6                                       Utilities
# 8                                       Utilities
# 10                                      Utilities
# 11                                      Utilities
# 15        Management of companies and enterprises
# 16                                      Utilities
# 19                                    Information
# 20        Management of companies and enterprises
# 22                                      Utilities
# 23                                      Utilities
# 25        Management of companies and enterprises
# 26        Professional, scientific, and technical
# 27                                      Utilities
# 28                                    Information
# 29  Mining, quarrying, and oil and gas extraction
# 30  Mining, quarrying, and oil and gas extraction
# 31                                      Utilities
# 32        Management of companies and enterprises
# 33            Arts, entertainment, and recreation
# 36                                      Utilities
# 39                                      Utilities
# 40                                      Utilities
# 41                                      Utilities
# 44     Agriculture, forestry, fishing and hunting
# 45  Mining, quarrying, and oil and gas extraction
# 47                                      Utilities
# 48                          Finance and insurance
# 51                                      Utilities
# 52        Professional, scientific, and technical
#
#     Number of Establishments_18  Employment_18  AverageSalary_21  \
# 6                          21.0         1379.0          131545.0
# 8                          60.0         1102.0          167135.0
# 10                          8.0          297.0          193516.0
# 11                         18.0          249.0          327267.0
# 15                        189.0        13823.0          440450.0
# 16                         17.0         2261.0          422364.0
# 19                        332.0        13487.0          147291.0
# 20                         65.0         2788.0          120442.0
# 22                         17.0          515.0          129600.0
# 23                         72.0         1411.0          118094.0
# 25                         45.0         1229.0          118519.0
# 26                       2686.0        22837.0          149187.0
# 27                         34.0         3897.0          179958.0
# 28                       2122.0        29376.0          149418.0
# 29                          3.0           75.0          142442.0
# 30                          4.0          893.0          235052.0
# 31                         28.0         1494.0          117065.0
# 32                         81.0         4097.0          243626.0
# 33                       4530.0        18533.0          120758.0
# 36                         41.0          703.0          265766.0
# 39                         13.0          285.0          115810.0
# 40                         18.0          350.0          114187.0
# 41                         13.0          140.0          118066.0
# 44                          4.0            4.0          152301.0
# 45                          5.0           16.0          115008.0
# 47                         30.0          781.0          166059.0
# 48                       1984.0        21595.0          180500.0
# 51                         25.0          768.0          160402.0
# 52                       6720.0        94501.0          204571.0
#
#                                 NAICS Description_21  \
# 6      Mining, quarrying, and oil and gas extraction
# 8            Management of companies and enterprises
# 10                                       Information
# 11                                       Information
# 15                                       Information
# 16                                       Information
# 19           Management of companies and enterprises
# 20                                         Utilities
# 22                         Industries not classified
# 23           Management of companies and enterprises
# 25                                         Utilities
# 26           Management of companies and enterprises
# 27     Mining, quarrying, and oil and gas extraction
# 28                                         Utilities
# 29               Arts, entertainment, and recreation
# 30                                         Utilities
# 31           Management of companies and enterprises
# 32               Arts, entertainment, and recreation
# 33                                         Utilities
# 36               Arts, entertainment, and recreation
# 39        Agriculture, forestry, fishing and hunting
# 40               Arts, entertainment, and recreation
# 41           Management of companies and enterprises
# 44                                         Utilities
# 45                                         Utilities
# 47                                       Information
# 48     Mining, quarrying, and oil and gas extraction
# 51  Professional, scientific, and technical services
# 52                         Industries not classified
#
#     Number of Establishments_21  Employment_21
# 6                           3.0           22.0
# 8                          60.0         4201.0
# 10                        418.0         8258.0
# 11                       1865.0        91735.0
# 15                        592.0        87171.0
# 16                        978.0        74674.0
# 19                         65.0         2336.0
# 20                         66.0         1520.0
# 22                          8.0            5.0
# 23                         21.0          277.0
# 25                         48.0         1084.0
# 26                        160.0         5522.0
# 27                         10.0         1266.0
# 28                         37.0         3967.0
# 29                       1016.0         1589.0
# 30                         11.0          308.0
# 31                         62.0         2049.0
# 32                       4828.0         7398.0
# 33                         17.0         1126.0
# 36                       4794.0        12332.0
# 39                          7.0          100.0
# 40                        396.0         4433.0
# 41                         52.0         1143.0
# 44                         11.0          379.0
# 45                         19.0          478.0
# 47                        807.0        20228.0
# 48                          8.0           40.0
# 51                       3878.0        62095.0
# 52                         10.0            7.0
